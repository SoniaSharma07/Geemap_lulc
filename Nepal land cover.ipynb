# %%
import ee  #import earth engine

# %%
#Initiate authentication for the Api
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=o9TwZXnZqVyY7qptjB3fLRL6nw0n8U-uhit2y9_7QQk&tc=X-czIvhAxcRd6S64DSf0PUkrQsYXbjf1iCwwzx_mwAg&cc=S1VMZ_DZ74yFTplIgkWUYSuX82aBTtenc-W2nOukCzA>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=o9TwZXnZqVyY7qptjB3fLRL6nw0n8U-uhit2y9_7QQk&tc=X-czIvhAxcRd6S64DSf0PUkrQsYXbjf1iCwwzx_mwAg&cc=S1VMZ_DZ74yFTplIgkWUYSuX82aBTtenc-W2nOukCzA</a></p>
#         <p>The authorization workflow will generate a code, which you
#         should paste in the box below</p>
# Enter verification code: 4/1AdQt8qhfgTqZOlqFO4MLn5Y5yA6bmkyserbVs1cGy82FRSGCrvduIR2tlMY
#
# Successfully saved authorization token.

# %%
import ee

# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=vf8vHPD66irmBnjLlU-K-Jmsf7ZJloJEDhxgPQRcpJA&tc=hhVvKAYQMi5irlwiRv8uERRKfqkdp4t9U-ap3W-HR_Q&cc=h9s6LvIbB7uN7qIoY8rUKcanbw5ZWgsmiO7lKCPfOhk>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=vf8vHPD66irmBnjLlU-K-Jmsf7ZJloJEDhxgPQRcpJA&tc=hhVvKAYQMi5irlwiRv8uERRKfqkdp4t9U-ap3W-HR_Q&cc=h9s6LvIbB7uN7qIoY8rUKcanbw5ZWgsmiO7lKCPfOhk</a></p>
#         <p>The authorization workflow will generate a code, which you
#         should paste in the box below</p>
# Enter verification code: 4/1AX4XfWhhhQhTmwptg3xhocPQ3xsUpWzX37ouUC1I2e4LzPaEMyhC7EUYQok
#
# Successfully saved authorization token.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [1], in <cell line: 7>()
#       4 ee.Authenticate()
#       6 # Initialize the library.
# ----> 7 ee.Initialize()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\__init__.py:128, in Initialize(credentials, opt_url, cloud_api_key, http_transport, project)
#     126 if credentials == 'persistent':
#     127   credentials = data.get_persistent_credentials()
# --> 128 data.initialize(
#     129     credentials=credentials,
#     130     api_base_url=(opt_url + '/api' if opt_url else None),
#     131     tile_base_url=opt_url,
#     132     cloud_api_base_url=opt_url,
#     133     cloud_api_key=cloud_api_key,
#     134     project=project,
#     135     http_transport=http_transport)
#     136 # Initialize the dynamically loaded functions on the objects that want them.
#     137 ApiFunction.initialize()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\data.py:201, in initialize(credentials, api_base_url, tile_base_url, cloud_api_base_url, cloud_api_key, project, http_transport)
#     197   _cloud_api_client_version = version
#     199 _http_transport = http_transport
# --> 201 _install_cloud_api_resource()
#     203 if project is not None:
#     204   _cloud_api_user_project = project
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\data.py:260, in _install_cloud_api_resource()
#     257 global _http_transport
#     259 timeout = (_deadline_ms / 1000.0) or None
# --> 260 _cloud_api_resource = _cloud_api_utils.build_cloud_resource(
#     261     _cloud_api_base_url,
#     262     credentials=_credentials,
#     263     api_key=_cloud_api_key,
#     264     timeout=timeout,
#     265     headers_supplier=_make_request_headers,
#     266     response_inspector=_handle_profiling_response,
#     267     http_transport=_http_transport)
#     269 _cloud_api_resource_raw = _cloud_api_utils.build_cloud_resource(
#     270     _cloud_api_base_url,
#     271     credentials=_credentials,
#    (...)
#     276     http_transport=_http_transport,
#     277     raw=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ee\_cloud_api_utils.py:130, in build_cloud_resource(api_base_url, api_key, credentials, timeout, headers_supplier, response_inspector, http_transport, raw)
#     126 discovery_service_url = (
#     127     '{}/$discovery/rest?version={}&prettyPrint=false'
#     128     .format(api_base_url, VERSION))
#     129 if http_transport is None:
# --> 130   http_transport = httplib2.Http(timeout=timeout)
#     131 if credentials is not None:
#     132   http_transport = AuthorizedHttp(credentials, http=http_transport)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\httplib2shim\__init__.py:117, in Http.__init__(self, cache, timeout, proxy_info, ca_certs, disable_ssl_certificate_validation, pool)
#     109 super(Http, self).__init__(
#     110     cache=cache,
#     111     timeout=timeout,
#     112     proxy_info=proxy_info,
#     113     ca_certs=ca_certs,
#     114     disable_ssl_certificate_validation=disable_ssl)
#     116 if not pool:
# --> 117     pool = self._make_pool(proxy_info=proxy_info)
#     119 self.pool = pool
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\httplib2shim\__init__.py:45, in _default_make_pool(http, proxy_info)
#      41 ssl_disabled = http.disable_ssl_certificate_validation
#      43 cert_reqs = 'CERT_REQUIRED' if http.ca_certs and not ssl_disabled else None
# ---> 45 if isinstance(proxy_info, collections.Callable):
#      46     proxy_info = proxy_info()
#      47 if proxy_info:
#
# AttributeError: module 'collections' has no attribute 'Callable'

# %%
 #Import the MODIS land cover collection.
lc = ee.ImageCollection('MODIS/006/MCD12Q1')

# %%
# Initial date of interest (inclusive).
i_date = '1992-01-01'

# Final date of interest (exclusive).
f_date = '2012-01-01'

# %%
# Define the urban location of interest as a point near Lyon, France.
u_lon = 84.1240
u_lat = 28.3949
u_poi = ee.Geometry.Point(u_lon, u_lat)

# %%
scale = 1000  # scale in meters

# %%
# Print the land cover type at the point.
lc_urban_point = lc.first().sample(u_poi, scale).first().get('LC_Type1').getInfo()
print('Land cover value at urban point is:', lc_urban_point)
# Out:
# Land cover value at urban point is: 2

# %%
# !pip install geemap
# Out:
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\Sonia\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Collecting geemap
#   Downloading geemap-0.10.1-py2.py3-none-any.whl (1.9 MB)
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
# Collecting geeadd>=0.5.1
#   Downloading geeadd-0.5.5-py3-none-any.whl (30 kB)
# Collecting folium>=0.11.0
#   Downloading folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
# Requirement already satisfied: numpy in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from geemap) (1.20.3)
# Collecting owslib
#   Downloading OWSLib-0.25.0-py2.py3-none-any.whl (216 kB)
# Collecting mss
#   Downloading mss-6.1.0-py3-none-any.whl (76 kB)
# Requirement already satisfied: pyshp>=2.1.3 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from geemap) (2.1.3)
# Collecting xyzservices
#   Downloading xyzservices-2021.11.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: matplotlib in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from geemap) (3.4.3)
# Collecting sankee
#   Downloading sankee-0.0.7.tar.gz (29 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting googledrivedownloader
#   Downloading googledrivedownloader-0.4-py2.py3-none-any.whl (3.9 kB)
# Requirement already satisfied: pandas in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from geemap) (1.3.3)
# Requirement already satisfied: click in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from geemap) (8.0.3)
# Requirement already satisfied: jupyterlab>=3 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from geemap) (3.2.1)
# Requirement already satisfied: pillow in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from geemap) (8.3.2)
# Requirement already satisfied: earthengine-api>=0.1.230 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from geemap) (0.1.284)
# Collecting pycrs
#   Downloading PyCRS-1.0.2.tar.gz (36 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ipyfilechooser>=0.6.0
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Collecting ipynb-py-convert
#   Downloading ipynb-py-convert-0.4.6.tar.gz (3.9 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting geojson
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Collecting ipytree
#   Downloading ipytree-0.2.1-py2.py3-none-any.whl (1.3 MB)
# Collecting ipyevents
#   Downloading ipyevents-2.0.1-py2.py3-none-any.whl (130 kB)
# Collecting palettable
#   Downloading palettable-3.3.0-py2.py3-none-any.whl (111 kB)
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Collecting python-box
#   Downloading python_box-5.4.1-py3-none-any.whl (21 kB)
# Collecting whiteboxgui>=0.6.0
#   Downloading whiteboxgui-0.6.0-py2.py3-none-any.whl (93 kB)
# Collecting ipyleaflet<=0.14.0
#   Downloading ipyleaflet-0.14.0-py2.py3-none-any.whl (3.3 MB)
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting bqplot
#   Downloading bqplot-0.12.31-py2.py3-none-any.whl (1.2 MB)
# Collecting voila
#   Downloading voila-0.3.0-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: future in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from earthengine-api>=0.1.230->geemap) (0.18.2)
# Requirement already satisfied: google-cloud-storage in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from earthengine-api>=0.1.230->geemap) (1.42.2)
# Requirement already satisfied: google-api-python-client<2,>=1.12.1 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from earthengine-api>=0.1.230->geemap) (1.12.8)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from earthengine-api>=0.1.230->geemap) (1.35.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from earthengine-api>=0.1.230->geemap) (0.1.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from earthengine-api>=0.1.230->geemap) (0.19.1)
# Requirement already satisfied: httplib2shim in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from earthengine-api>=0.1.230->geemap) (0.0.3)
# Requirement already satisfied: six in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from earthengine-api>=0.1.230->geemap) (1.16.0)
# Requirement already satisfied: requests in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from folium>=0.11.0->geemap) (2.26.0)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from folium>=0.11.0->geemap) (3.0.2)
# Collecting logzero>=1.5.0
#   Downloading logzero-1.7.0-py2.py3-none-any.whl (16 kB)
# Collecting beautifulsoup4>=4.9.0
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
# Requirement already satisfied: ipywidgets in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (7.6.5)
# Collecting traittypes<3,>=0.2.1
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab>=3->geemap) (6.1)
# Requirement already satisfied: ipython in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab>=3->geemap) (7.28.0)
# Requirement already satisfied: packaging in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab>=3->geemap) (21.0)
# Requirement already satisfied: nbclassic~=0.2 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab>=3->geemap) (0.3.2)
# Requirement already satisfied: jupyter-core in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab>=3->geemap) (4.8.1)
# Requirement already satisfied: jupyterlab-server~=2.3 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab>=3->geemap) (2.8.2)
# Requirement already satisfied: jupyter-server~=1.4 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab>=3->geemap) (1.11.1)
# Requirement already satisfied: whitebox in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from whiteboxgui>=0.6.0->geemap) (2.0.3)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from bqplot->geemap) (5.1.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from pandas->geemap) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from pandas->geemap) (2.8.2)
# Requirement already satisfied: colorama in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from click->geemap) (0.4.4)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->geemap) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->geemap) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->geemap) (1.3.2)
# Requirement already satisfied: pyyaml in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from owslib->geemap) (6.0)
# Requirement already satisfied: pyproj>=2 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from owslib->geemap) (3.2.1)
# Requirement already satisfied: ipykernel in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from sankee->geemap) (6.4.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from sankee->geemap) (5.1.3)
# Collecting plotly>=5.2.2
#   Downloading plotly-5.4.0-py2.py3-none-any.whl (25.3 MB)
# Collecting websockets>=9.0
#   Downloading websockets-10.1-cp39-cp39-win_amd64.whl (97 kB)
# Requirement already satisfied: jupyter-client<8,>=6.1.3 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from voila->geemap) (7.0.6)
# Requirement already satisfied: nbclient<0.6,>=0.4.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from voila->geemap) (0.5.4)
# Requirement already satisfied: nbconvert<7,>=6.0.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from voila->geemap) (6.2.0)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.1-py3-none-any.whl (37 kB)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (1.31.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (3.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (4.2.2)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (56.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (4.7.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.5.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.0.2)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from ipykernel->sankee->geemap) (0.1.3)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from ipykernel->sankee->geemap) (1.5.0)
# Requirement already satisfied: pygments in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from ipython->jupyterlab>=3->geemap) (2.10.0)
# Requirement already satisfied: decorator in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from ipython->jupyterlab>=3->geemap) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from ipython->jupyterlab>=3->geemap) (3.0.20)
# Requirement already satisfied: backcall in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from ipython->jupyterlab>=3->geemap) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from ipython->jupyterlab>=3->geemap) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from ipython->jupyterlab>=3->geemap) (0.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (2.0.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8,>=6.1.3->voila->geemap) (22.3.0)
# Requirement already satisfied: entrypoints in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8,>=6.1.3->voila->geemap) (0.3)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client<8,>=6.1.3->voila->geemap) (1.5.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyter-core->jupyterlab>=3->geemap) (302)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (3.3.4)
# Requirement already satisfied: prometheus-client in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (0.11.0)
# Requirement already satisfied: argon2-cffi in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (21.1.0)
# Requirement already satisfied: websocket-client in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (1.2.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (0.12.1)
# Requirement already satisfied: requests-unixsocket in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (0.2.0)
# Requirement already satisfied: Send2Trash in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (1.8.0)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (4.1.0)
# Requirement already satisfied: json5 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (0.9.6)
# Requirement already satisfied: babel in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (2.9.1)
# Requirement already satisfied: notebook<7 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from nbclassic~=0.2->jupyterlab>=3->geemap) (6.4.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from nbconvert<7,>=6.0.0->voila->geemap) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from nbconvert<7,>=6.0.0->voila->geemap) (1.5.0)
# Requirement already satisfied: testpath in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from nbconvert<7,>=6.0.0->voila->geemap) (0.5.0)
# Requirement already satisfied: defusedxml in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from nbconvert<7,>=6.0.0->voila->geemap) (0.7.1)
# Requirement already satisfied: bleach in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from nbconvert<7,>=6.0.0->voila->geemap) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from nbconvert<7,>=6.0.0->voila->geemap) (0.1.2)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from pyproj>=2->owslib->geemap) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from requests->folium>=0.11.0->geemap) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from requests->folium>=0.11.0->geemap) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from requests->folium>=0.11.0->geemap) (2.0.6)
# Requirement already satisfied: protobuf in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.230->geemap) (3.17.3)
# Requirement already satisfied: google-cloud-core<3.0dev,>=1.6.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.230->geemap) (2.0.0)
# Requirement already satisfied: google-resumable-media<3.0dev,>=1.3.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.230->geemap) (2.0.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (1.53.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from google-resumable-media<3.0dev,>=1.3.0->google-cloud-storage->earthengine-api>=0.1.230->geemap) (1.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jedi>=0.16->ipython->jupyterlab>=3->geemap) (0.8.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (21.2.0)
# Requirement already satisfied: wcwidth in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab>=3->geemap) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (0.4.8)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from terminado>=0.8.3->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.1.4)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from argon2-cffi->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.14.6)
# Requirement already satisfied: webencodings in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from bleach->nbconvert<7,>=6.0.0->voila->geemap) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\sonia\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server~=1.4->jupyterlab>=3->geemap) (2.20)
# Using legacy 'setup.py install' for ipynb-py-convert, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for pycrs, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for sankee, since package 'wheel' is not installed.
# Installing collected packages: tenacity, soupsieve, websockets, traittypes, ratelim, plotly, logzero, ipytree, ipyfilechooser, branca, beautifulsoup4, xyzservices, whiteboxgui, voila, sankee, python-box, pycrs, palettable, owslib, mss, ipynb-py-convert, ipyleaflet, ipyevents, googledrivedownloader, geojson, geocoder, geeadd, folium, ffmpeg-python, colour, bqplot, geemap
#     Running setup.py install for sankee: started
#     Running setup.py install for sankee: finished with status 'done'
#     Running setup.py install for pycrs: started
#     Running setup.py install for pycrs: finished with status 'done'
#     Running setup.py install for ipynb-py-convert: started
#     Running setup.py install for ipynb-py-convert: finished with status 'done'
# Successfully installed beautifulsoup4-4.10.0 bqplot-0.12.31 branca-0.4.2 colour-0.1.5 ffmpeg-python-0.2.0 folium-0.12.1.post1 geeadd-0.5.5 geemap-0.10.1 geocoder-1.38.1 geojson-2.5.0 googledrivedownloader-0.4 ipyevents-2.0.1 ipyfilechooser-0.6.0 ipyleaflet-0.14.0 ipynb-py-convert-0.4.6 ipytree-0.2.1 logzero-1.7.0 mss-6.1.0 owslib-0.25.0 palettable-3.3.0 plotly-5.4.0 pycrs-1.0.2 python-box-5.4.1 ratelim-0.1.6 sankee-0.0.7 soupsieve-2.3.1 tenacity-8.0.1 traittypes-0.2.1 voila-0.3.0 websockets-10.1 whiteboxgui-0.6.0 xyzservices-2021.11.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting geemap
#   Using cached geemap-0.10.1-py2.py3-none-any.whl (1.9 MB)
# Requirement already satisfied: pyshp>=2.1.3 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (2.1.3)
# Collecting pycrs
#   Using cached PyCRS-1.0.2.tar.gz (36 kB)
# Collecting ipyfilechooser>=0.6.0
#   Using cached ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Collecting ipytree
#   Using cached ipytree-0.2.1-py2.py3-none-any.whl (1.3 MB)
# Collecting geeadd>=0.5.1
#   Using cached geeadd-0.5.5-py3-none-any.whl (30 kB)
# Collecting googledrivedownloader
#   Using cached googledrivedownloader-0.4-py2.py3-none-any.whl (3.9 kB)
# Collecting ffmpeg-python
#   Using cached ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Collecting python-box
#   Using cached python_box-5.4.1-py3-none-any.whl (21 kB)
# Collecting jupyterlab>=3
#   Downloading jupyterlab-3.2.5-py3-none-any.whl (8.6 MB)
# Requirement already satisfied: pillow in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (7.1.2)
# Collecting ipynb-py-convert
#   Using cached ipynb-py-convert-0.4.6.tar.gz (3.9 kB)
# Collecting geocoder
#   Using cached geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
# Collecting earthengine-api>=0.1.230
#   Downloading earthengine-api-0.1.292.tar.gz (231 kB)
# Collecting sankee
#   Using cached sankee-0.0.7.tar.gz (29 kB)
# Requirement already satisfied: click in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (7.1.2)
# Collecting ipyleaflet<=0.14.0
#   Using cached ipyleaflet-0.14.0-py2.py3-none-any.whl (3.3 MB)
# Collecting geojson
#   Using cached geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Collecting whiteboxgui>=0.6.0
#   Using cached whiteboxgui-0.6.0-py2.py3-none-any.whl (93 kB)
# Collecting ipyevents
#   Using cached ipyevents-2.0.1-py2.py3-none-any.whl (130 kB)
# Collecting palettable
#   Using cached palettable-3.3.0-py2.py3-none-any.whl (111 kB)
# Requirement already satisfied: numpy in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (1.20.1)
# Collecting xyzservices
#   Using cached xyzservices-2021.11.0-py3-none-any.whl (34 kB)
# Collecting bqplot
#   Using cached bqplot-0.12.31-py2.py3-none-any.whl (1.2 MB)
# Collecting owslib
#   Using cached OWSLib-0.25.0-py2.py3-none-any.whl (216 kB)
# Collecting mss
#   Using cached mss-6.1.0-py3-none-any.whl (76 kB)
# Collecting voila
#   Using cached voila-0.3.0-py3-none-any.whl (1.7 MB)
# Collecting colour
#   Using cached colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pandas in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (1.2.3)
# Requirement already satisfied: matplotlib in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from geemap) (3.3.1)
# Collecting folium>=0.11.0
#   Using cached folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
# Requirement already satisfied: future in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages\future-0.18.2-py3.7.egg (from earthengine-api>=0.1.230->geemap) (0.18.2)
# Collecting google-cloud-storage
#   Downloading google_cloud_storage-1.43.0-py2.py3-none-any.whl (106 kB)
# Collecting google-api-python-client<2,>=1.12.1
#   Using cached google_api_python_client-1.12.8-py2.py3-none-any.whl (61 kB)
# Collecting google-auth>=1.4.1
#   Downloading google_auth-2.3.3-py2.py3-none-any.whl (155 kB)
# Collecting google-auth-httplib2>=0.0.3
#   Using cached google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting httplib2<1dev,>=0.9.2
#   Downloading httplib2-0.20.2-py3-none-any.whl (96 kB)
# Collecting httplib2shim
#   Using cached httplib2shim-0.0.3.tar.gz (17 kB)
# Requirement already satisfied: six in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from earthengine-api>=0.1.230->geemap) (1.15.0)
# Requirement already satisfied: requests in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from folium>=0.11.0->geemap) (2.25.1)
# Requirement already satisfied: jinja2>=2.9 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from folium>=0.11.0->geemap) (2.11.3)
# Collecting branca>=0.3.0
#   Using cached branca-0.4.2-py3-none-any.whl (24 kB)
# Collecting logzero>=1.5.0
#   Using cached logzero-1.7.0-py2.py3-none-any.whl (16 kB)
# Collecting beautifulsoup4>=4.9.0
#   Using cached beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.3.1-py3-none-any.whl (37 kB)
# Collecting uritemplate<4dev,>=3.0.0
#   Using cached uritemplate-3.0.1-py2.py3-none-any.whl (15 kB)
# Collecting google-api-core<2dev,>=1.21.0
#   Downloading google_api_core-1.31.5-py2.py3-none-any.whl (93 kB)
# Collecting google-auth>=1.4.1
#   Using cached google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
# Requirement already satisfied: packaging>=14.3 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (20.9)
# Requirement already satisfied: pytz in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages\pytz-2020.1-py3.7.egg (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (2020.1)
# Requirement already satisfied: setuptools>=40.3.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (52.0.0.post20210125)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.19.1-cp37-cp37m-win_amd64.whl (896 kB)
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading googleapis_common_protos-1.54.0-py2.py3-none-any.whl (207 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api>=0.1.230->geemap) (2.4.7)
# Requirement already satisfied: ipywidgets in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (7.4.2)
# Collecting traittypes<3,>=0.2.1
#   Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Collecting ipywidgets
#   Using cached ipywidgets-7.6.5-py2.py3-none-any.whl (121 kB)
# Requirement already satisfied: nbformat>=4.2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.0.7)
# Collecting jupyterlab-widgets>=1.0.0
#   Using cached jupyterlab_widgets-1.0.2-py3-none-any.whl (243 kB)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.1.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.3.3)
# Requirement already satisfied: ipython>=4.0.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.21.0)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.2-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: tornado>=4.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.1)
# Requirement already satisfied: jupyter-client in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.1.7)
# Requirement already satisfied: jedi>=0.16 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.18.0)
# Requirement already satisfied: pickleshare in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.5)
# Requirement already satisfied: backcall in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: decorator in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.4.2)
# Requirement already satisfied: pygments in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.7.0)
# Requirement already satisfied: colorama in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (1.1.1)
# Collecting jupyterlab-server~=2.3
#   Downloading jupyterlab_server-2.9.0-py3-none-any.whl (58 kB)
# Collecting nbclassic~=0.2
#   Downloading nbclassic-0.3.4-py3-none-any.whl (25 kB)
# Requirement already satisfied: jupyter-core in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jupyterlab>=3->geemap) (4.6.3)
# Collecting jupyter-server~=1.4
#   Downloading jupyter_server-1.13.1-py3-none-any.whl (396 kB)
# Requirement already satisfied: nbconvert in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (5.6.1)
# Requirement already satisfied: Send2Trash in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (1.5.0)
# Collecting websocket-client
#   Downloading websocket_client-1.2.3-py3-none-any.whl (53 kB)
# Requirement already satisfied: pyzmq>=17 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (19.0.2)
# Collecting argon2-cffi
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: prometheus-client in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (0.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jupyter-server~=1.4->jupyterlab>=3->geemap) (0.9.3)
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.4.0-py3-none-any.whl (78 kB)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab>=3->geemap) (3.7.4.3)
# Requirement already satisfied: idna>=2.8 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab>=3->geemap) (2.10)
# Requirement already satisfied: python-dateutil>=2.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.8.1)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (3.2.0)
# Collecting babel
#   Using cached Babel-2.9.1-py2.py3-none-any.whl (8.8 MB)
# Requirement already satisfied: json5 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (0.9.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jupyterlab-server~=2.3->jupyterlab>=3->geemap) (0.3)
# Requirement already satisfied: importlib-metadata in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (3.7.3)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (20.3.0)
# Requirement already satisfied: notebook<7 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nbclassic~=0.2->jupyterlab>=3->geemap) (5.7.10)
# Requirement already satisfied: defusedxml in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.7.1)
# Requirement already satisfied: bleach in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (3.3.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.8.4)
# Requirement already satisfied: testpath in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.4.4)
# Requirement already satisfied: wcwidth in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->folium>=0.11.0->geemap) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->folium>=0.11.0->geemap) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from requests->folium>=0.11.0->geemap) (4.0.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from terminado>=0.8.3->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.5.7)
# Collecting whitebox
#   Using cached whitebox-2.0.3-py2.py3-none-any.whl (70 kB)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.4->jupyterlab>=3->geemap) (1.14.5)
# Requirement already satisfied: pycparser in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.4->jupyterlab>=3->geemap) (2.20)
# Requirement already satisfied: webencodings in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab>=3->geemap) (0.5.1)
# Collecting ratelim
#   Using cached ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Collecting google-cloud-core<3.0dev,>=1.6.0
#   Downloading google_cloud_core-2.2.1-py2.py3-none-any.whl (29 kB)
# Collecting google-resumable-media<3.0dev,>=1.3.0
#   Downloading google_resumable_media-2.1.0-py2.py3-none-any.whl (75 kB)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.3.0-cp37-cp37m-win_amd64.whl (27 kB)
# Requirement already satisfied: zipp>=0.5 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from importlib-metadata->jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab>=3->geemap) (3.4.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geemap) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib->geemap) (0.10.0)
# Requirement already satisfied: pyyaml in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from owslib->geemap) (5.4.1)
# Collecting pyproj>=2
#   Downloading pyproj-3.2.1-cp37-cp37m-win_amd64.whl (6.2 MB)
# Collecting plotly>=5.2.2
#   Using cached plotly-5.4.0-py2.py3-none-any.whl (25.3 MB)
# Collecting tenacity>=6.2.0
#   Using cached tenacity-8.0.1-py3-none-any.whl (24 kB)
# Collecting websockets>=9.0
#   Downloading websockets-10.1-cp37-cp37m-win_amd64.whl (97 kB)
# Collecting voila
#   Downloading voila-0.2.16-py3-none-any.whl (1.6 MB)
# Collecting nbclient<0.6,>=0.4.0
#   Downloading nbclient-0.5.9-py3-none-any.whl (69 kB)
# Collecting voila
#   Downloading voila-0.2.15-py3-none-any.whl (1.6 MB)
#   Downloading voila-0.2.14-py3-none-any.whl (1.6 MB)
#   Downloading voila-0.2.13-py3-none-any.whl (1.6 MB)
#   Downloading voila-0.2.12-py3-none-any.whl (1.6 MB)
#   Downloading voila-0.2.11-py3-none-any.whl (1.6 MB)
#   Downloading voila-0.2.10-py3-none-any.whl (1.6 MB)
#   Downloading voila-0.2.9-py3-none-any.whl (1.6 MB)
#   Downloading voila-0.2.8-py3-none-any.whl (1.6 MB)
#   Downloading voila-0.2.7-py3-none-any.whl (2.5 MB)
#   Downloading voila-0.2.6-py3-none-any.whl (1.9 MB)
#   Downloading voila-0.2.5-py3-none-any.whl (1.9 MB)
#   Downloading voila-0.2.4-py3-none-any.whl (1.9 MB)
#   Downloading voila-0.2.3-py3-none-any.whl (6.9 MB)
#   Downloading voila-0.2.2-py3-none-any.whl (6.9 MB)
#   Downloading voila-0.2.1-py3-none-any.whl (6.9 MB)
#   Downloading voila-0.2.0-py3-none-any.whl (6.9 MB)
#   Downloading voila-0.1.24-py3-none-any.whl (5.9 MB)
# Collecting jupyterlab-pygments<0.2,>=0.1.0
#   Using cached jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting async-generator
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting voila
#   Downloading voila-0.1.23-py3-none-any.whl (5.9 MB)
#   Downloading voila-0.1.22-py3-none-any.whl (5.9 MB)
#   Downloading voila-0.1.21-py3-none-any.whl (5.9 MB)
#   Downloading voila-0.1.20-py3-none-any.whl (5.9 MB)
#   Downloading voila-0.1.19-py3-none-any.whl (5.9 MB)
#   Downloading voila-0.1.18.post1-py2.py3-none-any.whl (5.9 MB)
#   Downloading voila-0.1.18-py2.py3-none-any.whl (5.9 MB)
#   Downloading voila-0.1.17-py2.py3-none-any.whl (4.8 MB)
#   Downloading voila-0.1.16-py2.py3-none-any.whl (4.8 MB)
#   Downloading voila-0.1.15-py2.py3-none-any.whl (4.8 MB)
#   Downloading voila-0.1.14-py2.py3-none-any.whl (4.8 MB)
#   Downloading voila-0.1.13-py2.py3-none-any.whl (4.8 MB)
#   Downloading voila-0.1.12-py2.py3-none-any.whl (4.8 MB)
#   Downloading voila-0.1.11-py2.py3-none-any.whl (4.8 MB)
#   Downloading voila-0.1.10-py2.py3-none-any.whl (4.8 MB)
#   Downloading voila-0.1.9-py2.py3-none-any.whl (4.8 MB)
#   Downloading voila-0.1.8-py2.py3-none-any.whl (4.8 MB)
#   Downloading voila-0.1.7-py2.py3-none-any.whl (4.8 MB)
#   Downloading voila-0.1.6-py2.py3-none-any.whl (4.8 MB)
#   Downloading voila-0.1.5-py2.py3-none-any.whl (4.9 MB)
#   Downloading voila-0.1.4-py2.py3-none-any.whl (5.5 MB)
#   Downloading voila-0.1.3-py2.py3-none-any.whl (7.3 MB)
#   Downloading voila-0.1.2-py2.py3-none-any.whl (7.3 MB)
#   Downloading voila-0.1.1-py2.py3-none-any.whl (7.3 MB)
#   Downloading voila-0.1.0.tar.gz (7.3 MB)
#   Downloading voila-0.0.14-py2.py3-none-any.whl (7.3 MB)
#   Downloading voila-0.0.13-py2.py3-none-any.whl (7.3 MB)
#   Downloading voila-0.0.12-py2.py3-none-any.whl (7.3 MB)
#   Downloading voila-0.0.11-py2.py3-none-any.whl (7.3 MB)
#   Downloading voila-0.0.10-py2.py3-none-any.whl (6.8 MB)
# Building wheels for collected packages: earthengine-api, httplib2shim, ipynb-py-convert, pycrs, sankee
#   Building wheel for earthengine-api (setup.py): started
#   Building wheel for earthengine-api (setup.py): finished with status 'done'
#   Created wheel for earthengine-api: filename=earthengine_api-0.1.292-py3-none-any.whl size=261930 sha256=8599db10af0bca9f18100f888f44ea74651e457e1347d3a01896c2646c2517f6
#   Stored in directory: c:\users\sonia\appdata\local\pip\cache\wheels\07\11\15\ec39d3e08cd319e74b7d0d269c4b6b0ee5afd3998417345ded
#   Building wheel for httplib2shim (setup.py): started
#   Building wheel for httplib2shim (setup.py): finished with status 'done'
#   Created wheel for httplib2shim: filename=httplib2shim-0.0.3-py2.py3-none-any.whl size=18059 sha256=8a389cd4f776afdc4a8ddc12af7387cf2f90df003ca0618fced7b924d62aea24
#   Stored in directory: c:\users\sonia\appdata\local\pip\cache\wheels\b7\3d\b4\033d07bc6a387ce6e16807fe14d4b780d84c78e54dc73a3568
#   Building wheel for ipynb-py-convert (setup.py): started
#   Building wheel for ipynb-py-convert (setup.py): finished with status 'done'
#   Created wheel for ipynb-py-convert: filename=ipynb_py_convert-0.4.6-py3-none-any.whl size=4625 sha256=e3da13b6581d4afb894c4ac976cebb0df8fc3a42b982a3e37b9c81d4802460ad
#   Stored in directory: c:\users\sonia\appdata\local\pip\cache\wheels\af\31\a9\761b134adbbca3c92d491eff3bad785c0a0c0079695d6f0504
#   Building wheel for pycrs (setup.py): started
#   Building wheel for pycrs (setup.py): finished with status 'done'
#   Created wheel for pycrs: filename=PyCRS-1.0.2-py3-none-any.whl size=32680 sha256=b0392118773ae6c60a5ac8cb647d52c1f2d235aac597fa1034b51c106de91d31
#   Stored in directory: c:\users\sonia\appdata\local\pip\cache\wheels\3e\ce\32\1ec0aba6b9770681a423e82f0274c57d09ad2c20c2864901f9
#   Building wheel for sankee (setup.py): started
#   Building wheel for sankee (setup.py): finished with status 'done'
#   Created wheel for sankee: filename=sankee-0.0.7-py3-none-any.whl size=27626 sha256=551ca0bc3e8d17b84c7a33d72bede00c121230864a75ab4950462e328dd15854
#   Stored in directory: c:\users\sonia\appdata\local\pip\cache\wheels\13\28\83\5726f82a8cb0baf76169d99ee0595c420afedb9020e22bbd4b
# Successfully built earthengine-api httplib2shim ipynb-py-convert pycrs sankee
# Installing collected packages: pyasn1, rsa, pyasn1-modules, protobuf, cachetools, googleapis-common-protos, google-auth, sniffio, httplib2, google-crc32c, google-api-core, argon2-cffi-bindings, widgetsnbextension, websocket-client, uritemplate, jupyterlab-widgets, google-resumable-media, google-cloud-core, google-auth-httplib2, argon2-cffi, anyio, tenacity, soupsieve, jupyter-server, ipywidgets, httplib2shim, google-cloud-storage, google-api-python-client, babel, whitebox, traittypes, ratelim, pyproj, plotly, nbclassic, logzero, jupyterlab-server, ipytree, ipyfilechooser, earthengine-api, branca, beautifulsoup4, xyzservices, whiteboxgui, voila, sankee, python-box, pycrs, palettable, owslib, mss, jupyterlab, ipynb-py-convert, ipyleaflet, ipyevents, googledrivedownloader, geojson, geocoder, geeadd, folium, ffmpeg-python, colour, bqplot, geemap
# Successfully installed anyio-3.4.0 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 babel-2.9.1 beautifulsoup4-4.10.0 bqplot-0.12.31 branca-0.4.2 cachetools-4.2.4 colour-0.1.5 earthengine-api-0.1.292 ffmpeg-python-0.2.0 folium-0.12.1.post1 geeadd-0.5.5 geemap-0.10.1 geocoder-1.38.1 geojson-2.5.0 google-api-core-1.31.5 google-api-python-client-1.12.8 google-auth-1.35.0 google-auth-httplib2-0.1.0 google-cloud-core-2.2.1 google-cloud-storage-1.43.0 google-crc32c-1.3.0 google-resumable-media-2.1.0 googleapis-common-protos-1.54.0 googledrivedownloader-0.4 httplib2-0.20.2 httplib2shim-0.0.3 ipyevents-2.0.1 ipyfilechooser-0.6.0 ipyleaflet-0.14.0 ipynb-py-convert-0.4.6 ipytree-0.2.1 ipywidgets-7.6.5 jupyter-server-1.13.1 jupyterlab-3.2.5 jupyterlab-server-2.9.0 jupyterlab-widgets-1.0.2 logzero-1.7.0 mss-6.1.0 nbclassic-0.3.4 owslib-0.25.0 palettable-3.3.0 plotly-5.4.0 protobuf-3.19.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycrs-1.0.2 pyproj-3.2.1 python-box-5.4.1 ratelim-0.1.6 rsa-4.8 sankee-0.0.7 sniffio-1.2.0 soupsieve-2.3.1 tenacity-8.0.1 traittypes-0.2.1 uritemplate-3.0.1 voila-0.0.10 websocket-client-1.2.3 whitebox-2.0.3 whiteboxgui-0.6.0 widgetsnbextension-3.5.2 xyzservices-2021.11.0
#   WARNING: The scripts pyrsa-decrypt.exe, pyrsa-encrypt.exe, pyrsa-keygen.exe, pyrsa-priv2pub.exe, pyrsa-sign.exe and pyrsa-verify.exe are installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script wsdump.exe is installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-server.exe is installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pybabel.exe is installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script whitebox.exe is installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyproj.exe is installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-nbclassic.exe is installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script earthengine.exe is installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script voila.exe is installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script mss.exe is installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jlpm.exe, jupyter-lab.exe, jupyter-labextension.exe and jupyter-labhub.exe are installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script ipynb-py-convert.exe is installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script geocode.exe is installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script geeadd.exe is installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script geemap.exe is installed in 'C:\Users\Sonia\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !pip install installpyleaflet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement installpyleaflet
# ERROR: No matching distribution found for installpyleaflet

# %%
# !pip install ipyleaflet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipyleaflet in c:\users\sonia\appdata\roaming\python\python37\site-packages (0.14.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\sonia\appdata\roaming\python\python37\site-packages (from ipyleaflet) (0.2.1)
# Requirement already satisfied: ipywidgets<8,>=7.6.0 in c:\users\sonia\appdata\roaming\python\python37\site-packages (from ipyleaflet) (7.6.5)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\sonia\appdata\roaming\python\python37\site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\sonia\appdata\roaming\python\python37\site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet) (1.0.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet) (4.3.3)
# Requirement already satisfied: nbformat>=4.2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet) (5.0.7)
# Requirement already satisfied: ipython>=4.0.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet) (7.21.0)
# Requirement already satisfied: jupyter-client in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet) (6.1.7)
# Requirement already satisfied: tornado>=4.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet) (6.1)
# Requirement already satisfied: jedi>=0.16 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (3.0.5)
# Requirement already satisfied: pickleshare in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.7.5)
# Requirement already satisfied: backcall in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.2.0)
# Requirement already satisfied: colorama in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.4.4)
# Requirement already satisfied: pygments in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (2.7.0)
# Requirement already satisfied: setuptools>=18.5 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (52.0.0.post20210125)
# Requirement already satisfied: decorator in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (4.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.8.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet) (4.6.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet) (1.15.0)
# Requirement already satisfied: importlib-metadata in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet) (3.7.3)
# Requirement already satisfied: wcwidth in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (5.7.10)
# Requirement already satisfied: pyzmq>=17 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (19.0.2)
# Requirement already satisfied: terminado>=0.8.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.9.3)
# Requirement already satisfied: jinja2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (2.11.3)
# Requirement already satisfied: Send2Trash in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (1.5.0)
# Requirement already satisfied: prometheus-client in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.8.0)
# Requirement already satisfied: nbconvert<6.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (5.6.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7.6.0->ipyleaflet) (2.8.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (1.4.3)
# Requirement already satisfied: bleach in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (3.3.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.3)
# Requirement already satisfied: defusedxml in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.7.1)
# Requirement already satisfied: testpath in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (1.1.1)
# Requirement already satisfied: pywinpty>=0.5 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.5.7)
# Requirement already satisfied: packaging in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (20.9)
# Requirement already satisfied: webencodings in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (0.5.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.6.0->ipyleaflet) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from packaging->bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.6.0->ipyleaflet) (2.4.7)
