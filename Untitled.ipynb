# %%
from glob import glob
import rasterio as rio
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap
import earthpy as et
import plotly.graph_objects as go

# %%
np.seterr(divide = 'ignore', invalid = 'ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
import rasterio

# %%
from rasterio.plot import show

# %%
data =glob('*.tif')

# %%
data
# Out:
# ['a.tif',
#  'median1-0000000000-0000013568.tif',
#  'median1-0000000000-0000027136.tif',
#  'median1-0000013568-0000000000.tif',
#  'median1-0000013568-0000013568.tif',
#  'median1-0000013568-0000027136.tif']

# %%
data_to_mosaic =[]

# %%
data_to_mosaic
# Out:
# [<open DatasetReader name='a.tif' mode='r'>,
#  <open DatasetReader name='median1-0000000000-0000013568.tif' mode='r'>,
#  <open DatasetReader name='median1-0000000000-0000027136.tif' mode='r'>,
#  <open DatasetReader name='median1-0000013568-0000000000.tif' mode='r'>,
#  <open DatasetReader name='median1-0000013568-0000013568.tif' mode='r'>,
#  <open DatasetReader name='median1-0000013568-0000027136.tif' mode='r'>]
